# %%
from bs4 import BeautifulSoup
import requests
#USE PYTHON ANACADONA 3.8.5 to RUN

# %%
url= "http://onlinecollegebasketball.org/game/1028201"
page = requests.get(url)
soup = BeautifulSoup(page.text,"html")

# %%
infoList = soup.find_all("td",class_="left")

'''
gameData = {
  "awayTeam":{
    "name": infoList[1].text.replace("\xa0"," "),
    "teamCode":(infoList[1].find("a").get("href")).split("/")[2],
    "players":[],
    "totalShots":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]},
    "totalDriving":[0,0],
    "defense" : {"man-to-man": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]},
    "zone":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]},
    "pressure":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]},
    "transition": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]}}
  }
  ,
  "homeTeam":{
    "name": infoList[2].text.replace("\xa0"," "),
    "teamCode":(infoList[2].find("a").get("href")).split("/")[2],
    "players":[],
    "totalShots":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]},
    "totalDriving":[0,0],
    "defense" : {"man-to-man": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]},
    "zone":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]},
    "pressure":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]},
    "transition": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]}}
  }
}
'''

#'''
gameData = {
  "awayTeam":{
    "name": infoList[1].text.replace("\xa0"," "),
    "teamCode":(infoList[1].find("a").get("href")).split("/")[2],
    "players":[],
    "totalShots":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]},
    "totalDriving":[0,0],
    "defense" : {"man-to-man": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
                 "man-to-man defense packed" : {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
                 "man-to-man defense extended" : {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},    
    "zone":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "zone defense packed":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "zone defense extended":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "pressure":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "transition": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "half-court": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]}}
  }
  ,
  "homeTeam":{
    "name": infoList[2].text.replace("\xa0"," "),
    "teamCode":(infoList[2].find("a").get("href")).split("/")[2],
    "players":[],
    "totalShots":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]},
    "totalDriving":[0,0],
    "defense" : {"man-to-man": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
                 "man-to-man defense packed" : {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
                 "man-to-man defense extended" : {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},    
    "zone":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "zone defense packed":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "zone defense extended":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "pressure":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "transition": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "half-court": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]}}
  }
}
  

#'''

# %%
teamSwitch = 0 
curTeam = "awayTeam"
infoListPlayers = infoList[4:]  # cuts it to the first player in BoxScore

for i in range(len(infoListPlayers)):
    if len(infoListPlayers[i].text.split("\xa0")) == 3:
        name, position = infoListPlayers[i].text.split("\xa0")[1:]
        
        # Append a new player dictionary if the player index exceeds the current list length
        if len(gameData[curTeam]["players"]) <= i:
            gameData[curTeam]["players"].append({"name": name, "position": position.upper(), "shots": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]}, "driving": [0, 0]})
        else:
            # Update existing player information
            gameData[curTeam]["players"][i]["name"] = name
            gameData[curTeam]["players"][i]["position"] = position.upper()
            gameData[curTeam]["players"][i]["shots"] = {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]}
            gameData[curTeam]["players"][i]["driving"] = [0, 0]

        # Switch the team if the next player is "Total" and the current team is "homeTeam"
        if infoListPlayers[i + 1].text == "Total" and curTeam == "awayTeam":
            curTeam = "homeTeam"

# %%
playbyText = soup.find_all("div",id="Boxscore")[1].text
gameArr = playbyText.split("\n")
tipOff = gameArr[10]

# %%
x = soup.find_all("div",id="Boxscore")[1]
teamEventArr = x.find_all("b")[3:] #shows time and Team for each play-by-play Event (lined up with gameStartArr)

#Lines up the events of gameEventsArr and teamEventArr
gameEventsArr = gameArr[10:] # play-by-play Events
for i in gameEventsArr:
  if i == "":
    gameEventsArr.remove(i)

# %%
#Changes all Exclamations to Periods
for i in range(len(gameEventsArr)):
  gameEventsArr[i] = gameEventsArr[i].replace("!",".")
gameEventsArr = gameEventsArr[:-1]

# %%
#Delete "Game Event","2nd Half","Overtime" and lines w/o ":" from gameEventsArr 
'''
gameEventsArr = [string for string in gameEventsArr if "Game Event" not in string]
gameEventsArr = [string for string in gameEventsArr if "2nd Half" not in string]
gameEventsArr = [string for string in gameEventsArr if "Overtime" not in string]
gameEventsArr = [string for string in gameEventsArr if ":" in string]
'''
gameEventsArr = [
    string for string in gameEventsArr
    if "Game Event" not in string
    and "2nd Half" not in string
    and "Overtime" not in string
    and ":" in string
]
print(gameEventsArr[2])
# Out:
#   19:35 - Assumption: Murphy brings up the ball against man-to-man defense.   Murphy passes the ball to Lewis. Lewis passes the ball to Murphy on the perimeter. Murphy tries to drive to the basket, but is stopped.   Murphy passes the ball to Pruitt in the paint. Pruitt shoots from the inside.  The shot goes in.   Assumption 5 - 3.

# %%
#Deletes time of play-by-play, Makes it easier to get the Offensive Team


for i in range(len(gameEventsArr)):
  dash = "-"
  index = 0
  while(dash != gameEventsArr[i][index]):
      index += 1
  gameEventsArr[i] = gameEventsArr[i][index + 2:]
# Out:
# '\n\nfor i in range(len(gameEventsArr)):\n  dash = "-"\n  index = 0\n  while(dash != gameEventsArr[i][index]):\n      index += 1\n  gameEventsArr[i] = gameEventsArr[i][index + 2:]\n'

# %%
#Determines whether a drive is successful or not
Driving = {
  "Fail":"drive ",
  "Success":"drives "
}

# %%
#Adds all the drivers
drive_attempt = -1 #-1: No Drive, 0: Fail, 1: Success
for event in gameEventsArr:
  if Driving["Fail"] in event or Driving["Success"] in event:
    drive_attempt = 0
    if Driving["Success"] in event:
      drive_attempt = 1
    words = event.split()
    team = words[0][:-1] #team of driver
    if drive_attempt == 0:
      drive_index = words.index("drive")
      player_index = drive_index - 3
    else:
      drive_index = words.index("drives")
      player_index = drive_index - 1
    player_name = words[player_index] #driver name

    
    if team in gameData["homeTeam"]["name"]:
      team = "homeTeam"
    else:
      team = "awayTeam"
    
    for player in gameData[team]["players"]:
      if player["name"] == player_name:
        player["driving"][0] += drive_attempt
        player["driving"][1] += 1
        gameData[team]["totalDriving"][0] += drive_attempt
        gameData[team]["totalDriving"][1] += 1

# %%
#Delete Game Events with Non-And One Fouls (second free throws occur) and Charging Fouls
gameEventsArr = [string for string in gameEventsArr if "second free throw" not in string or "blocking out" in string]
gameEventsArr = [string for string in gameEventsArr if "charged with the foul" not in string]

print(gameEventsArr[0])
# Out:
#   19:55 - Assumption: Murphy brings up the ball against man-to-man defense.   Murphy passes the ball to Schwarz in the paint. Schwarz shoots from the low post.  The shot goes in.   Assisted by Murphy.   And Schwarz is fouled on the shot, will shoot an added free throw.   Schwarz makes the first free throw.   Assumption 3 - 0.

# %%
shotTypes = {    
    "Inside Shot": ["shoots from the inside","shoots from the low post", "shoots in the paint", "shoots from inside the arc", "shoots from the block","tips it in","attempts to dunk it" , "lays it up", "goes for the dunk"],
    "Mid-Range": ["with a fadeaway jumper","shoots a jumper"],
    "3-Pointer": ["shoots from beyond the arc","shoots from well beyond the arc","shoots from the three point line", "shoots from deep" , "shoots from the corner","shoots from downtown"]
}

Finishing = {"attempts to dunk it" , "lays it up", "goes for the dunk"}

Turnover = {"turns the ball over", "steals the pass"}

# %%
#Adds every FG into the gameData per Player
for event in gameEventsArr:
  print(event)
  #Adds turnovers in defense (not offensive fouls)
  if "turns the ball over" in event or "steals the pass" in event:

    words = event.split()
    team = words[0][:-1]
    
    if team in gameData["homeTeam"]["name"]:
      team = "homeTeam"
      oppTeam = "awayTeam"  
    else:
      team = "awayTeam"
      oppTeam = "homeTeam"

    try:
      defense = [defense for defense in gameData["awayTeam"]["defense"] if defense in event][-1]
      
    except IndexError:
      #print(event)
      defense = "half-court"
    
    
    gameData[oppTeam]["defense"][defense]["Turnovers"][0] += 1
    gameData[oppTeam]["defense"][defense]["Turnovers"][1] += 1 #Defense event counter [forced turnovers,defensive events occured]
    
  #For searching shots
  for shot_type, shots in shotTypes.items():
    for shot in shots:
      shot_attempt = 0
      if shot in event:
        words = event.split()
        player_index = words.index(shot.split()[0]) - 1
        player_name = words[player_index]
        team = words[0][:-1]
        print(team)

        

        #Finds the type of defense (doesn't matter for gameData["team"])
        try:
          defense = [defense for defense in gameData["awayTeam"]["defense"] if defense in event][-1]
          
          

        except IndexError:
          defense = "half-court"
        
        

        if "Slam dunk" in event or "shot goes in" in event or "tips it in" == shot:
          shot_attempt = 1
        

        #For Fast-breaks

        if ("Breakaway" in event or "Fast break opportunity" in event) and "slow it down" not in event:
          defense = "transition"
          if shot in Finishing:
            shot_type = "Finishing"

        #For Drives
        if shot in Finishing and "drives" in event and words[words.index("drives") - 1] == player_name:
          shot_type = "Finishing"
        
        
            

        #finds player and accumlates the shot in gameData
        if team in gameData["homeTeam"]["name"]:
          team = "homeTeam"
          oppTeam = "awayTeam"
          
        else:
          team = "awayTeam"
          oppTeam = "homeTeam"
        
        
          
      
        for player in gameData[team]["players"]:
          
          
          
          if player["name"] == player_name:
            
            player["shots"][shot_type][0] += shot_attempt
            player["shots"][shot_type][1] += 1
            gameData[team]["totalShots"][shot_type][0] += shot_attempt
            gameData[team]["totalShots"][shot_type][1] += 1

            gameData[oppTeam]["defense"][defense][shot_type][0] += shot_attempt
            gameData[oppTeam]["defense"][defense][shot_type][1] += 1

            #print(defense)
            gameData[oppTeam]["defense"][defense]["Turnovers"][1] += 1 #Defense event counter [forced turnovers,defensive events occured]

gameData
# Out:
#   19:55 - Assumption: Murphy brings up the ball against man-to-man defense.   Murphy passes the ball to Schwarz in the paint. Schwarz shoots from the low post.  The shot goes in.   Assisted by Murphy.   And Schwarz is fouled on the shot, will shoot an added free throw.   Schwarz makes the first free throw.   Assumption 3 - 0.
# 19:5
#   19:46 - Western New England: Roberts brings up the ball against a zone defense.   Roberts passes the ball to Bair on the perimeter. Bair shoots from beyond the arc.  The shot goes in.   Assisted by Roberts.   Tied 3 - 3.
# 19:4
#   19:35 - Assumption: Murphy brings up the ball against man-to-man defense.   Murphy passes the ball to Lewis. Lewis passes the ball to Murphy on the perimeter. Murphy tries to drive to the basket, but is stopped.   Murphy passes the ball to Pruitt in the paint. Pruitt shoots from the inside.  The shot goes in.   Assumption 5 - 3.
# 19:3
#   19:14 - Western New England: Roberts brings up the ball against pressure defense.   Roberts passes the ball to Blank in the paint. Blank passes the ball to Starks in the paint. Starks passes the ball to Blank in the paint. Blank passes the ball to Roberts on the perimeter. Roberts shoots from the three point line.  The shot goes in.   Western New England 6 - 5.
# 19:1
#   18:44 - Assumption: Shaffer brings up the ball against a zone defense.   Shaffer passes the ball to Perkins. Perkins passes the ball to Lewis. Lewis shoots a jumper from the elbow.  The shot misses.   Seifert grabs the rebound.
# 18:4
#   18:29 - Western New England: Akahoshi brings up the ball against pressure defense.   Akahoshi passes the ball to Seifert. Seifert passes the ball to Akahoshi outside. Akahoshi passes the ball to Bair. Bair shoots a jumper.  The shot misses.   Pruitt grabs the rebound.
# 18:2
#   18:06 - Assumption: Fast break opportunity.   Shaffer leads the fast break with Lewis to the right.   Shaffer passes the ball to Lewis on the perimeter. Lewis shoots from the three point line.  The shot misses.   Starks grabs the rebound.
# 18:0
#   18:02 - Western New England: Fast break opportunity.   Edwards leads the fast break with Akahoshi to the right.   Edwards passes the ball to Akahoshi on the perimeter. Akahoshi shoots from the three point line.  The shot misses.   Walker grabs the rebound.
# 18:0
#   17:58 - Assumption: Shaffer brings up the ball against man-to-man defense.   Shaffer passes the ball to Lewis on the perimeter. Lewis shoots from the three point line.  The shot goes in.   Assisted by Shaffer.   Assumption 8 - 6.
# 17:5
#   17:47 - Western New England: Akahoshi brings up the ball against a zone defense.   Akahoshi tries to drive to the basket, but is stopped.   Akahoshi passes the ball to Bair. Bair with a fadeaway jumper.  The shot misses.   Lewis grabs the rebound.
# 17:4
#   17:32 - Assumption: Fast break opportunity.   Perkins leads the fast break, but decides to slow it down and run the half-court offense.   Perkins passes the ball to Lewis in the paint. Offensive foul.  Lewis commits the foul.
#   17:20 - Western New England: Akahoshi brings up the ball against pressure defense.   Akahoshi passes the ball to Edwards in the paint. Foul.  Shaffer commits a foul away from the ball.
#   17:00 - Assumption: Shaffer brings up the ball against a zone defense.   Shaffer drives by Akahoshi.   Shaffer passes the ball to Perkins on the perimeter. Perkins shoots from the three point line.  The shot misses.   Lewis grabs the long offensive rebound.
# 17:0
#   16:52 - Assumption: Lewis has the rebound and restarts the offense.   Lewis passes the ball to Shaffer on the perimeter. Shaffer shoots from beyond the arc.  The shot misses.   Bair grabs the long rebound.
# 16:5
#   16:41 - Western New England: Fast break opportunity.   Edwards leads the fast break, but decides to slow it down and run the half-court offense.   Edwards passes the ball to Akahoshi in the paint. Akahoshi passes the ball to Edwards on the perimeter. Edwards passes the ball to Bair in the paint. Bair shoots from the low post.  The shot misses.   Pruitt grabs the rebound.
# 16:4
#   16:10 - Assumption: Fast break opportunity.   Perkins leads the fast break, but decides to slow it down and run the half-court offense.   Perkins passes the ball to Walker in the paint. Walker shoots in the paint.  The shot misses.   Pruitt grabs the offensive rebound.
# 16:1
#   15:53 - Assumption: Pruitt has the rebound.   Pruitt shoots from the low post.  The shot misses.   Seifert grabs the rebound.
# 15:5
#   15:51 - Western New England: Akahoshi brings up the ball against a zone defense.   Akahoshi passes the ball to Edwards. Edwards passes the ball to Akahoshi outside. Foul.  Lewis commits a foul away from the ball.
#   15:24 - Assumption: Shaffer brings up the ball against man-to-man defense.   Shaffer passes the ball to Jaramillo. Jaramillo passes the ball to Shaffer in the paint. Shaffer shoots in the paint.  The shot misses.   Pruitt grabs the offensive rebound.
# 15:2
#   15:06 - Assumption: Pruitt has the rebound and restarts the offense.   Pruitt shoots from the low post.  The shot goes in.   Assumption 10 - 9.
# 15:0
#   15:03 - Western New England: Roberts brings up the ball against man-to-man defense.   Roberts passes the ball to Akahoshi. Akahoshi carelessly turns the ball over out of bounds.
#   14:58 - Assumption: Shaffer brings up the ball against a zone defense.   Shaffer passes the ball to Pruitt in the paint. Pruitt passes the ball to Shaffer outside. Shaffer passes the ball to Perkins on the perimeter. Perkins shoots from the three point line.  The shot goes in.   Assumption 13 - 9.
# 14:5
#   14:18 - Assumption: Shaffer brings up the ball against man-to-man defense.   Shaffer tries to drive to the basket, but is stopped.   Shaffer passes the ball to Jaramillo. Jaramillo with a fadeaway jumper.  The shot misses.   Roberts grabs the rebound.
# 14:1
#   14:11 - Western New England: Fast break opportunity.   Edwards leads the fast break, but decides to slow it down and run the half-court offense.   Edwards passes the ball to Akahoshi in the paint. Akahoshi shoots in the paint.  Walker rotates over and blocks the shot.   Walker grabs the rebound.
# 14:1
#   13:53 - Assumption: Fast break opportunity.   Shaffer leads the fast break with Perkins and Jaramillo.   Shaffer lays it up.  The shot goes in.   Assumption 15 - 11.
# 13:5
#   13:49 - Western New England: Roberts brings up the ball against man-to-man defense.   Roberts passes the ball to Starks on the perimeter. Starks hands off the ball to Roberts. Roberts shoots from the corner.  The shot misses.   Shaffer grabs the rebound.
# 13:4
#   13:17 - Assumption: Shaffer brings up the ball against man-to-man defense.   Shaffer passes the ball to Perkins outside. Perkins passes the ball to Shaffer. Shaffer passes the ball to Jaramillo in the paint. Jaramillo shoots in the paint.  The shot misses.   Akahoshi grabs the rebound.
# 13:1
#   5:43 - Western New England: Edwards brings up the ball against pressure defense.   Murphy steals the pass from Edwards.
#   5:39 - Assumption: Fast break opportunity.   Perkins leads the fast break, but decides to slow it down and run the half-court offense.   Perkins passes the ball to Schwarz in the paint. Schwarz shoots from the low post.  The shot goes in.   Assisted by Perkins.   Assumption 41 - 25.
# 5:3
#   5:21 - Assumption: Murphy brings up the ball against man-to-man defense.   Murphy passes the ball to Black. Black with a fadeaway jumper.  The shot misses.   Jaramillo grabs the offensive rebound.
# 5:2
#   5:12 - Assumption: Jaramillo has the rebound.   Jaramillo shoots from the low post.  Blank rotates over and blocks the shot.   Blank grabs the rebound.
# 5:1
#   5:10 - Western New England: Fast break opportunity.   Edwards leads the fast break with Roberts to the right.   Edwards passes the ball to Roberts on the perimeter. Roberts shoots from beyond the arc.  The shot goes in.   Assisted by Edwards.   Assumption 41 - 28.
# 5:1
#   4:51 - Western New England: Roberts brings up the ball against pressure defense.   Roberts passes the ball to Edwards on the perimeter. Edwards shoots from the three point line.  The shot goes in.   Assisted by Roberts.   Assumption 42 - 31.
# 4:5
#   4:43 - Assumption: Murphy brings up the ball against a zone defense.   Murphy passes the ball to Pruitt on the perimeter. Pruitt passes the ball to Perkins on the perimeter. Perkins passes the ball to Lewis. Lewis shoots a jumper.  The shot goes in.   Assisted by Perkins.   Assumption 44 - 31.
# 4:4
#   4:24 - Western New England: Roberts brings up the ball against man-to-man defense extended out to the arc.   Roberts tries to drive to the basket, but is stopped.   Roberts with a fadeaway jumper.  The shot goes in.   Assumption 44 - 33.
# 4:2
#   4:12 - Assumption: Murphy brings up the ball against man-to-man defense.   Murphy passes the ball to Schwarz in the paint. Schwarz passes the ball to Murphy in the paint. Offensive foul.  Murphy commits the foul.
#   4:03 - Western New England: Edwards brings up the ball against a zone defense extended out to the arc.   Edwards passes the ball to Starks. Starks passes the ball to Roberts in the paint. Schwarz steals the pass from Roberts.
#   3:41 - Western New England: Roberts brings up the ball against pressure defense.   Roberts drives down the lane.   Roberts lays it up.  The shot goes in.   Assumption 46 - 35.
# 3:4
#   3:31 - Assumption: Murphy brings up the ball against a zone defense.   Murphy passes the ball to Lewis on the perimeter. Lewis shoots from the three point line.  The shot goes in.   Assumption 49 - 35.
# 3:3
#   3:20 - Western New England: Roberts brings up the ball against a zone defense extended out to the arc.   Roberts passes the ball to Edwards in the paint. Edwards passes the ball to Roberts on the perimeter. Roberts shoots from the three point line.  The shot misses.   Pruitt grabs the long rebound.
# 3:2
#   3:02 - Assumption: Perkins brings up the ball against man-to-man defense.   Starks steals the pass from Perkins.
#   2:57 - Western New England: Fast break opportunity.   Roberts leads the fast break with Edwards to the right.   Roberts passes the ball to Edwards at the basket. Edwards attempts to dunk it.  Slam dunk.   Assisted by Roberts.   Assumption 49 - 37.
# 2:5
#   2:52 - Assumption: Murphy brings up the ball against man-to-man defense.   Murphy passes the ball to Perkins on the perimeter. Perkins passes the ball to Lewis. Lewis passes the ball to Pruitt on the perimeter. Pruitt shoots from the three point line.  The shot misses.   Blank grabs the rebound.
# 2:5
#   2:29 - Western New England: Roberts brings up the ball against pressure defense.   Roberts passes the ball to Blank in the paint. Blank shoots from the low post.  The shot misses.   Schwarz grabs the rebound.
# 2:2
#   2:08 - Western New England: Edwards brings up the ball against man-to-man defense extended out to the arc.   Edwards passes the ball to Starks outside. Starks passes the ball to Roberts on the perimeter. Roberts shoots from the corner.  The shot goes in.   Assisted by Starks.   Assumption 51 - 40.
# 2:0
#   1:52 - Assumption: Murphy brings up the ball against man-to-man defense.   Murphy passes the ball to Perkins on the perimeter. Perkins shoots from the three point line.  The shot goes in.   Assisted by Murphy.   Assumption 54 - 40.
# 1:5
#   1:42 - Western New England: Roberts brings up the ball against pressure defense.   Roberts passes the ball to Bair in the paint. Bair passes the ball to Edwards in the paint. Edwards shoots from the inside.  Schwarz rotates over and blocks the shot.   Schwarz grabs the rebound.
# 1:4
#   1:22 - Assumption: Murphy brings up the ball against a zone defense.   Murphy passes the ball to Pruitt. Pruitt shoots a jumper from the elbow.  It's blocked by Roberts.   Lewis grabs the offensive rebound.
# 1:2
#   1:11 - Assumption: Lewis has the rebound and restarts the offense.   Lewis passes the ball to Schwarz in the paint. Schwarz goes for the dunk.  Slam dunk.   Assisted by Lewis.   Assumption 56 - 40.
# 1:1
#   1:03 - Western New England: Edwards brings up the ball against a zone defense extended out to the arc.   Edwards passes the ball to Blank in the paint. Blank passes the ball to Starks in the paint. Starks passes the ball to Blank in the paint. Blank passes the ball to Bair in the paint. Bair shoots from the inside.  The shot misses.   Foul.  Pruitt fouls Starks blocking out to get the rebound.   In the double bonus, Starks is shooting two free throws.   Starks makes the first free throw.   Starks makes the second free throw.   Assumption 56 - 42.
# 1:0
#   0:36 - Assumption: Murphy brings up the ball against a zone defense.   Murphy passes the ball to Perkins on the perimeter. Perkins shoots from the three point line.  The shot misses.   Edwards grabs the rebound.
# 0:3
#   0:25 - Western New England: Roberts brings up the ball against man-to-man defense extended out to the arc.   Roberts passes the ball to Blank in the paint. Blank passes the ball to Starks outside. Starks passes the ball to Roberts on the perimeter. Roberts tries to drive to the basket, but is stopped.   Roberts with a fadeaway jumper.  The shot goes in.   Assumption 56 - 44.
# 0:2
#   19:55 - Western New England: The ball is inbounded to Starks.   Starks passes the ball to Seifert in the paint. Seifert passes the ball to Starks. Starks passes the ball to Seifert. Perkins steals the pass from Seifert.
#   19:34 - Assumption: Fast break opportunity.   Perkins leads the fast break with Murphy to the right.   Perkins passes the ball to Murphy on the perimeter. Murphy shoots from the three point line.  The shot misses.   Perkins grabs the long offensive rebound.
# 19:3
#   19:30 - Assumption: Perkins has the rebound and restarts the offense.   Perkins shoots from deep.  The shot misses.   Bair grabs the rebound.
# 19:3
#   19:24 - Western New England: Edwards brings up the ball against a zone defense extended out to the arc.   Edwards passes the ball to Roberts on the perimeter. Roberts shoots from the three point line.  The shot misses.   Seifert grabs the long offensive rebound.
# 19:2
#   19:14 - Western New England: Seifert has the rebound and restarts the offense.   Seifert passes the ball to Roberts on the perimeter. Roberts passes the ball to Bair on the perimeter. Bair shoots from the three point line.  The shot misses.   Roberts grabs the long offensive rebound.
# 19:1
#   18:57 - Western New England: Roberts has the rebound and restarts the offense.   Roberts passes the ball to Edwards on the perimeter. Foul.  Jaramillo commits the foul on Edwards.
#   18:53 - Western New England: The ball is inbounded to Blank.   Blank passes the ball to Edwards on the perimeter. Edwards tries to drive to the basket, but is stopped.   Edwards passes the ball to Blank in the paint. Blank shoots in the paint.  The shot goes in.   Assisted by Edwards.   Assumption 56 - 46.
# 18:5
#   18:40 - Assumption: Shaffer brings up the ball against man-to-man defense.   Shaffer passes the ball to Pruitt in the paint. Pruitt passes the ball to Lewis on the perimeter. Lewis shoots from the three point line.  The shot goes in.   Assisted by Pruitt.   Assumption 59 - 46.
# 18:4
#   18:10 - Assumption: Perkins brings up the ball against man-to-man defense extended out to the arc.   Perkins passes the ball to Lewis. Lewis passes the ball to Walker in the paint. Walker shoots from the inside.  The shot misses.   Pruitt grabs the offensive rebound.
# 18:1
#   17:53 - Assumption: Pruitt has the rebound and restarts the offense.   Pruitt shoots from the block.  The shot goes in.   Assumption 61 - 47.
# 17:5
#   17:48 - Western New England: Roberts brings up the ball against man-to-man defense extended out to the arc.   Roberts passes the ball to Starks outside. Starks passes the ball to Edwards. Edwards passes the ball to Starks in the paint. Starks passes the ball to Roberts. Roberts passes the ball to Edwards. Edwards shoots a jumper.  The shot goes in.   Assisted by Roberts.   Assumption 61 - 49.
# 17:4
#   17:19 - Assumption: Black brings up the ball against man-to-man defense.   Black passes the ball to Walker in the paint. Walker passes the ball to Perkins outside. Starks steals the pass from Perkins.
#   17:06 - Western New England: Fast break opportunity.   Edwards attacks with the ball on the fast break.   Edwards passes the ball to Bair on the perimeter. Bair shoots from the three point line.  The shot misses.   Pruitt grabs the rebound.
# 17:0
#   17:00 - Assumption: Perkins brings up the ball against man-to-man defense.   Perkins passes the ball to Black on the perimeter. Black passes the ball to Perkins. Perkins with a fadeaway jumper.  The shot goes in.   Assisted by Black.   Assumption 63 - 49.
# 17:0
#   16:45 - Western New England: Edwards brings up the ball against pressure defense.   Pruitt steals the pass from Edwards.
#   16:35 - Western New England: Roberts brings up the ball against pressure defense.   Roberts passes the ball to Edwards on the perimeter. Edwards shoots from the three point line.  The shot goes in.   Assumption 65 - 52.
# 16:3
#   16:22 - Assumption: Black brings up the ball against man-to-man defense.   Black passes the ball to Lewis on the perimeter. Lewis shoots from the three point line.  The shot misses.   Blank grabs the rebound.
# 16:2
#   16:14 - Western New England: Roberts brings up the ball against a zone defense extended out to the arc.   Roberts passes the ball to Blank in the paint. Blank passes the ball to Roberts on the perimeter. Roberts shoots from beyond the arc.  Air ball.   Walker grabs the rebound.
# 16:1
#   15:57 - Assumption: Black brings up the ball against man-to-man defense.   Black passes the ball to Lewis on the perimeter. Lewis shoots from the three point line.  The shot goes in.   Assisted by Black.   Assumption 68 - 52.
# 15:5
#   15:45 - Western New England: Roberts brings up the ball against man-to-man defense extended out to the arc.   Roberts passes the ball to Edwards on the perimeter. Edwards passes the ball to Roberts in the paint. Roberts shoots from the inside.  The shot misses.   Walker grabs the rebound.
# 8:4
#   8:33 - Western New England: Roberts brings up the ball against man-to-man defense.   Roberts passes the ball to Bair in the paint. Bair shoots from the low post.  The shot goes in.   Assisted by Roberts.   Assumption 85 - 66.
# 8:3
#   8:25 - Assumption: Murphy brings up the ball against man-to-man defense extended out to the arc.   Murphy passes the ball to Lay on the perimeter. Lay carelessly turns the ball over out of bounds.
#   8:21 - Western New England: Roberts brings up the ball against a zone defense.   Roberts passes the ball to Edwards outside. Edwards passes the ball to Roberts. Roberts shoots a jumper from the elbow.  The shot misses.   Lay grabs the rebound.
# 8:2
#   8:03 - Assumption: Murphy brings up the ball against a zone defense extended out to the arc.   Murphy passes the ball to Schwarz in the paint. Schwarz goes for the dunk.  Slam dunk.   Assumption 87 - 66.
# 8:0
#   7:51 - Western New England: Roberts brings up the ball against man-to-man defense.   Roberts passes the ball to Bair outside. Bair passes the ball to Blank in the paint. Lay steals the pass from Blank.
#   7:33 - Assumption: Fast break opportunity.   Jaramillo leads the fast break with Murphy and Lewis.   Jaramillo passes the ball to Murphy on the perimeter. Murphy shoots from beyond the arc.  The shot goes in.   Assisted by Jaramillo.   Assumption 90 - 66.
# 7:3
#   7:12 - Assumption: Murphy brings up the ball against man-to-man defense extended out to the arc.   Murphy passes the ball to Lewis outside. Lewis tries to drive to the basket, but is stopped.   Lewis with a fadeaway jumper.  The shot goes in.   Assumption 92 - 68.
# 7:1
#   6:58 - Western New England: Roberts brings up the ball against man-to-man defense.   Roberts passes the ball to Blank in the paint. Blank shoots from the low post.  The shot goes in.   Assisted by Roberts.   Assumption 92 - 70.
# 6:5
#   6:44 - Assumption: Murphy brings up the ball against a zone defense extended out to the arc.   Murphy drives down the lane.   Murphy passes the ball to Lay on the perimeter. Lay shoots from the three point line.  The shot goes in.   Assisted by Murphy.   Assumption 95 - 70.
# 6:4
#   6:35 - Western New England: Roberts brings up the ball against a zone defense.   Roberts tries to drive to the basket, but is stopped.   Roberts with a fadeaway jumper.  The shot misses.   Jaramillo grabs the rebound.
# 6:3
#   6:26 - Assumption: Murphy brings up the ball against man-to-man defense extended out to the arc.   Murphy passes the ball to Schwarz in the paint. Schwarz passes the ball to Lay on the perimeter. Lay tries to drive to the basket, but is stopped.   Lay turns the ball over to the other team.
#   6:04 - Western New England: Fast break opportunity.   Edwards leads the fast break, but decides to slow it down and run the half-court offense.   Edwards passes the ball to Roberts on the perimeter. Roberts passes the ball to Blank in the paint. Blank shoots from the low post.  The shot goes in.   Assumption 95 - 72.
# 6:0
#   5:40 - Assumption: Murphy brings up the ball against man-to-man defense extended out to the arc.   Murphy passes the ball to Lewis on the perimeter. Lewis shoots from the corner.  The shot misses.   Murphy grabs the long offensive rebound.
# 5:4
#   5:30 - Assumption: Murphy has the rebound and restarts the offense.   Murphy passes the ball to Pruitt in the paint. Pruitt shoots from the low post.  The shot goes in.   Assisted by Murphy.   Assumption 97 - 72.
# 5:3
#   5:24 - Western New England: Roberts brings up the ball against man-to-man defense.   Roberts shoots from well beyond the arc.  The shot misses.   Lewis grabs the rebound.
# 1:5
#   1:42 - Assumption: Murphy brings up the ball against man-to-man defense extended out to the arc.   Murphy passes the ball to Schwarz in the paint. Schwarz goes for the dunk.  Slam dunk.   Assisted by Murphy.   Assumption 113 - 79.
# 1:4
#   1:34 - Western New England: Edwards brings up the ball against pressure defense.   Edwards passes the ball to Seifert in the paint. Seifert passes the ball to Starks in the paint. Starks shoots from the low post.  Schwarz rotates over and blocks the shot.   Bair grabs the offensive rebound.
# 1:3
#   1:21 - Western New England: Bair has the rebound and restarts the offense.   Pruitt steals the pass from Bair.
#   1:16 - Assumption: Fast break opportunity.   Perkins leads the fast break, but decides to slow it down and run the half-court offense.   Perkins passes the ball to Lewis outside. Lewis drives down the lane.   Lewis passes the ball to Perkins at the basket. Perkins lays it up.  The shot goes in.   Assisted by Lewis.   Assumption 115 - 79.
# 1:1
#   0:47 - Assumption: Murphy brings up the ball against a zone defense extended out to the arc.   Murphy passes the ball to Schwarz outside. Schwarz passes the ball to Murphy on the perimeter. Murphy tries to drive to the basket, but is stopped.   Murphy with a fadeaway jumper.  The shot goes in.   Assumption 117 - 81.
# 0:4
#   0:23 - Western New England: Akahoshi brings up the ball against pressure defense.   Assumption is fatigued and are showing low defensive energy.   Akahoshi passes the ball to Edwards on the perimeter. Edwards passes the ball to Starks in the paint. Starks passes the ball to Bair outside. Bair shoots from deep.  The shot misses.   Bair grabs the long offensive rebound.
# 0:2
# {'awayTeam': {'name': 'Western New England Golden Bears',
#   'teamCode': '968',
#   'players': [{'name': 'Bair',
#     'position': 'SF',
#     'shots': {'Finishing': [0, 1],
#      'Inside Shot': [3, 5],
#      'Mid-Range': [1, 4],
#      '3-Pointer': [1, 6]},
#     'driving': [1, 2]},
#    {'name': 'Starks',
#     'position': 'PF',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 1],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [1, 1]},
#    {'name': 'Blank',
#     'position': 'C',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [4, 7],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'Edwards',
#     'position': 'SG',
#     'shots': {'Finishing': [1, 1],
#      'Inside Shot': [2, 3],
#      'Mid-Range': [1, 1],
#      '3-Pointer': [3, 4]},
#     'driving': [0, 1]},
#    {'name': 'Roberts',
#     'position': 'PG',
#     'shots': {'Finishing': [1, 1],
#      'Inside Shot': [1, 2],
#      'Mid-Range': [2, 5],
#      '3-Pointer': [3, 12]},
#     'driving': [3, 6]},
#    {'name': 'Akahoshi',
#     'position': 'PG',
#     'shots': {'Finishing': [1, 1],
#      'Inside Shot': [0, 1],
#      'Mid-Range': [1, 3],
#      '3-Pointer': [2, 5]},
#     'driving': [0, 3]},
#    {'name': 'Curry',
#     'position': 'SF',
#     'shots': {'Finishing': [1, 1],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [1, 1]},
#    {'name': 'Seifert',
#     'position': 'PF',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]}],
#   'totalShots': {'Finishing': [4, 5],
#    'Inside Shot': [10, 19],
#    'Mid-Range': [5, 13],
#    '3-Pointer': [9, 27]},
#   'totalDriving': [6, 14],
#   'defense': {'man-to-man': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'man-to-man defense packed': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'man-to-man defense extended': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'zone': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'zone defense packed': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'zone defense extended': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'pressure': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'transition': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'half-court': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]}}},
#  'homeTeam': {'name': 'Assumption Greyhounds',
#   'teamCode': '533',
#   'players': [{'name': 'Lewis',
#     'position': 'SF',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'Pruitt',
#     'position': 'PF',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'Schwarz',
#     'position': 'C',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'Perkins',
#     'position': 'SG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'Murphy',
#     'position': 'PG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'Walker',
#     'position': 'C',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'Lay',
#     'position': 'PF',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'Shaffer',
#     'position': 'PG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'Jaramillo',
#     'position': 'SF',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'Black',
#     'position': 'SG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]}],
#   'totalShots': {'Finishing': [0, 0],
#    'Inside Shot': [0, 0],
#    'Mid-Range': [0, 0],
#    '3-Pointer': [0, 0]},
#   'totalDriving': [0, 0],
#   'defense': {'man-to-man': {'Finishing': [0, 0],
#     'Inside Shot': [5, 5],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 5],
#     'Turnovers': [10, 20]},
#    'man-to-man defense packed': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'man-to-man defense extended': {'Finishing': [0, 0],
#     'Inside Shot': [1, 2],
#     'Mid-Range': [4, 4],
#     '3-Pointer': [1, 3],
#     'Turnovers': [3, 12]},
#    'zone': {'Finishing': [0, 1],
#     'Inside Shot': [0, 1],
#     'Mid-Range': [1, 4],
#     '3-Pointer': [2, 4],
#     'Turnovers': [0, 10]},
#    'zone defense packed': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'zone defense extended': {'Finishing': [0, 0],
#     'Inside Shot': [1, 2],
#     'Mid-Range': [0, 2],
#     '3-Pointer': [0, 3],
#     'Turnovers': [2, 9]},
#    'pressure': {'Finishing': [1, 1],
#     'Inside Shot': [1, 4],
#     'Mid-Range': [0, 1],
#     '3-Pointer': [3, 4],
#     'Turnovers': [6, 16]},
#    'transition': {'Finishing': [2, 2],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [2, 4],
#     'Turnovers': [0, 6]},
#    'half-court': {'Finishing': [1, 1],
#     'Inside Shot': [2, 5],
#     'Mid-Range': [0, 2],
#     '3-Pointer': [1, 4],
#     'Turnovers': [3, 15]}}}}
